# %% [markdown]
# # NoSQL Databases - Quiz
#
#
# ## Introduction
#
# In this lesson, we'll try our luck with some common open-ended interview questions about NoSQL databases.
#
#
# ## Question 1
#
# What is the difference between a NoSQL and a SQL database?  Which is better?
#
# Write your answer below this line:
# Sql has a rigid table format whereas nosql does not have that requirement
# _______________________________________________________________________________________________________________________________
#
#
#
#
#
#
#
# ## Question 2
#
# Describe a situation where a NoSQL database might be a better choice than a relational database, and explain your reasoning.
#
# Write your answer below this line:
# When making a row for each instance of data would require too much redundant data or would have unnecesary runtime. For ex Facebook friend network would need the ability to look at your friends profiles. You can either have a row for each link, Which you would then need to find each link or have it represented as a graph and have all the links stored with the profile
# _______________________________________________________________________________________________________________________________
#
#
#
#
#
#
# ## Question 3
#
# How does MongoDB work? How is it different from a relational database?
#
# Write your answer below this line:
# Its a document based db which has a key to arbitrary document size
# _______________________________________________________________________________________________________________________________
#
#
#
#
#
#
#
#
# ## Question 4
#
# What is fault tolerance, and what does it have to do with Resilient Distributed Datasets?
#
# Write your answer below this line:
# Distributed Databases may fail, and as such need the ability to account for such a failure
# _______________________________________________________________________________________________________________________________
#
#
#
#
#
#
#
#
# ## Question 5
#
# What is MapReduce? How is it related to Hadoop?
#
# Write your answer below this line:
# Map - send a function to each database seperately
# Reduce - aggregate the results
#
# Hadoop is a set up for a distributed database system.
# Map reduce lets large problems be solved by multiple machines
# _______________________________________________________________________________________________________________________________
#
#
#
#
# ## Summary
#
#
# In this lesson, we reviewed some common NoSQL interview questions.
